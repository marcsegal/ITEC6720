# %%
import pandas as pd
import numpy as np

df = pd.read_csv('weblist1.csv')

df.head()
# Out:
#       Lidya E Validator Name Validator Name.1  \
# 0    Emmanuel     Immaculate     Hasini, Abel
# 1    Emmanuel     Immaculate     Hasini, Abel
# 2    Emmanuel     Immaculate      Minna, Abel
# 3  Oluwatosin       Emmanuel           Amusan
# 4  Oluwatosin       Emmanuel           Amusan
#
#                        Smart contract address  \
# 0    0154676f95a510a855622f8ac9b07816f94edf08
# 1    075b26e9656afa11197ebc2377f593d2cc1db26b
# 2    0dfe2caf3a2a7a1b16aff26434f78f0b29491c06
# 3    0e95242dceab8815a44767f6ef2b20a693765e56
# 4  0x14F37B574242D366558dB61f3335289a5035c506
#
#                                       Blog post link     Chain  \
# 0  https://consensys.io/diligence/audits/2024/01/...  Ethereum
# 1  https://consensys.io/diligence/audits/2024/01/...  Ethereum
# 2  https://consensys.io/diligence/audits/2021/02/...  Ethereum
# 3  https://hacken.io/case-studies/auditing-sock-e...  Ethereum
# 4  https://blog.openzeppelin.com/hackergold-bug-a...  Optimism
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519 entries, 0 to 518
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Lidya E                 519 non-null    object
#  1   Validator Name          516 non-null    object
#  2   Validator Name.1        519 non-null    object
#  3   Smart contract address  519 non-null    object
#  4   Blog post link          516 non-null    object
#  5   Chain                   494 non-null    object
#  6   Audit Website           511 non-null    object
#  7   Source Link 1           517 non-null    object
#  8   Source Link 2           197 non-null    object
#  9   Source Link 3           104 non-null    object
#  10  Date Added              518 non-null    object
# dtypes: object(11)
# memory usage: 44.7+ KB

# %%
df_duplicates = df.duplicated ('Smart contract address')

df_duplicates
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 514     True
# 515     True
# 516     True
# 517    False
# 518    False
# Length: 519, dtype: bool
